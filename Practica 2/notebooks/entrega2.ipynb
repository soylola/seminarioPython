# %%
import sys
sys.path.append('../src')

# %%
import ejercicio1
import ejercicio2
import ejercicio3
import ejercicio10

# %%
ejercicio1.text_statistics(ejercicio1.text)

# %%
ejercicio2.playlist_duration(ejercicio2.playlist)

# %%
ejercicio3.filter_spoilers(ejercicio3.review)

# %%
ejercicio10.print_final_table(ejercicio10.rounds)
